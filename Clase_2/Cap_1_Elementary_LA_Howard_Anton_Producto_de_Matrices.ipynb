# %% [markdown]
# ### Conjunto de ejercicios 1.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import sympy as sy

# %%
# Creamos las matrices aleatoriamente
np.random.seed(123)
A = np.random.randint(-10,10,size = (4,5))
print('La matriz A es:',A,sep='\n\n')
B = np.random.randint(-20,20,size = (4,5))
print()
print('La matriz B es:',B,sep='\n\n')
C = np.random.randint(5,50,size = (5,2))
print()
print('La matriz C es:',C,sep='\n\n')
D = np.random.randint(10,100,size = (4,2))
print()
print('La matriz D es:',D,sep='\n\n')
E = np.random.randint(0,20,size = (5,4))
print()
print('La matriz E es:',E,sep='\n\n')
# Out:
# La matriz A es:
#
# [[  3  -8  -8  -4   7]
#  [  9   0  -9 -10   7]
#  [  5  -1 -10   4 -10]
#  [  5   9   4  -6 -10]]
#
# La matriz B es:
#
# [[ -4 -16 -17 -18   0]
#  [ 19 -18   0 -13  15]
#  [  8  18  13   1  10]
#  [  7  14  13  -8 -17]]
#
# La matriz C es:
#
# [[47 10]
#  [ 5 16]
#  [39 15]
#  [27 18]
#  [23 41]]
#
# La matriz D es:
#
# [[25 37]
#  [40 62]
#  [80 36]
#  [90 16]]
#
# La matriz E es:
#
# [[14  7 11  7]
#  [ 1 11  5 18]
#  [17 12 18 17]
#  [ 1 19 12  9]
#  [16 17  3  3]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# RESOLUCION 1. (a)
try:   
    res_1  = B @ A #--> la dimension de B es de 4x5 y de A es de 4x5, por tanto el producto no esta definido.
    print(res_1)
except ValueError: 
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Lo sentimos, las dimensiones de las matrices no permiten el producto.

# %%
# RESOLUCION 1. (b)
res_2 = np.dot(A,B.T) # la matriz A es de 4x5 , y la transpuesta de B es de 5x4, por lo tanto el producto esta definido.
print("La matriz de AB^T es :",res_2, sep = '\n\n')
# Out:
# La matriz de AB^T es :
#
# [[ 324  358 -158 -282]
#  [ 297  406   15  -93]
#  [  94  -89 -204   29]
#  [-124 -139  148  431]]

# %%
# RESOLUCION 1. (c)
res_c = A.dot(C) + D # Dimension de A es 4x5, dimension de C 5x2, producto definido. Dimension del producto resultante 4x2
                     # Dimension de D es 4x2, entonces el producto AC + D esta definido, por tener mismas dimensiones.
print("La matriz de AC+D es :",res_c, sep = '\n\n')
# Out:
# La matriz de AC+D es :
#
# [[-133   34]
#  [   3  124]
#  [-202 -418]
#  [ 134 -248]]

# %%
# RESOLUCION 1. (d) 

print("Dimension de A",A.shape)
print("Dimension de E",E.shape)
print("Dimension de C",C.shape)

res_d = E@(A@C) # Matriz E dimension: 5x4, Matriz A dimension: 4x5, Matriz C dimension: 5X2, por lo tanto la matriz resultante
                # esta definida.
print("La matriz resultante es :",res_d, sep = '\n\n')
# Out:
# Dimension de A (4, 5)
# Dimension de E (5, 4)
# Dimension de C (5, 2)
# La matriz resultante es :
#
# [[ -5265  -6450]
#  [ -1183  -6343]
#  [ -7458 -11967]
#  [ -3849  -6649]
#  [ -3871  -1148]]

# %%
# RESOLUCION 1. (e)
res_e = A - 3*E.T # Dimension de A: 4x5, Dimension de E 5x4, Dimension de la tranpuesta de E: 4x5, 
                  # El multiplicar por un escalar no altera la dimension de E, entonces la resta esta definida.
print("La matriz resultante es :",res_e, sep = '\n\n')
# Out:
# La matriz resultante es :
#
# [[-39 -11 -59  -7 -41]
#  [-12 -33 -45 -67 -44]
#  [-28 -16 -64 -32 -19]
#  [-16 -45 -47 -33 -19]]

# %%
# RESOLUCION 1. (f)
print("Dimension de E",E.shape)
print("Dimension de B",B.shape)
print("Dimension de A",A.shape)

res_f = E @ (5*B + A)
print("La matriz resultante es :",res_f, sep = '\n\n')
# Out:
# Dimension de E (5, 4)
# Dimension de B (4, 5)
# Dimension de A (4, 5)
# La matriz resultante es :
#
# [[ 1265  -330  -277 -2064   447]
#  [ 2072   789  1325 -1702  -601]
#  [ 2449   369   474 -3118   208]
#  [ 2859   -19  1017 -1825  1190]
#  [ 1751 -2434 -1269 -2890  1341]]

# %%
# RESOLUCION 2. (a)
print("Dimension de C",C.shape)
print("Dimension de D",D.shape)
t_d = D.T
print("Dimension de la transpuesta de D",t_d.shape)
res2_a = C @ D.T
print("La matriz resultante es :",res2_a, sep = '\n\n')
# Out:
# Dimension de C (5, 2)
# Dimension de D (4, 2)
# Dimension de la transpuesta de D (2, 4)
# La matriz resultante es :
#
# [[1545 2500 4120 4390]
#  [ 717 1192  976  706]
#  [1530 2490 3660 3750]
#  [1341 2196 2808 2718]
#  [2092 3462 3316 2726]]

# %%
np.dot(C,D.T)
# Out:
# array([[1545, 2500, 4120, 4390],
#        [ 717, 1192,  976,  706],
#        [1530, 2490, 3660, 3750],
#        [1341, 2196, 2808, 2718],
#        [2092, 3462, 3316, 2726]])

# %%
# RESOLUCION 2. (b)
try:
    print("Dimension de A",A.shape)
    print("Dimension de B",B.shape)
    t_b = B.T
    print("Dimension de la transpuesta de B",t_b.shape)
    print("La matriz resultante del producto de A.B^t será",A.shape[0],'x',t_b.shape[1])
    res2_b = A.dot(B.T)
    print("La matriz resultante es :",res2_b, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de A (4, 5)
# Dimension de B (4, 5)
# Dimension de la transpuesta de B (5, 4)
# La matriz resultante del producto de A.B^t será 4 x 4
# La matriz resultante es :
#
# [[ 324  358 -158 -282]
#  [ 297  406   15  -93]
#  [  94  -89 -204   29]
#  [-124 -139  148  431]]

# %%
# RESOLUCION 2. (c)
try:
    print("Dimension de B",B.shape)
    print("Dimension de C",C.shape)
    print("Dimension de D",D.shape)
    print("La matriz resultante del producto de BC - 3D será",B.shape[0],'x',C.shape[1])
    res2_c = np.dot(B,C) - 3*D
    print("La matriz resultante es :",res2_c, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de B (4, 5)
# Dimension de C (5, 2)
# Dimension de D (4, 2)
# La matriz resultante del producto de BC - 3D será 4 x 2
# La matriz resultante es :
#
# [[-1492  -986]
#  [  677    97]
#  [  990   883]
#  [   29  -400]]

# %%
# RESOLUCION 2. (d)
try:
    print("Dimension de D",D.shape)
    t_d = D.T
    print("Dimension de la transpuesta de D",t_d.shape)
    print("Dimension de B",B.shape)
    print("Dimension de E",E.shape)
    print("La matriz resultante del producto de BC - 3D será",t_d.shape[0],'x',E.shape[1])
    res2_d = t_d@(B@E)
    print("La matriz resultante es :",res2_d, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de D (4, 2)
# Dimension de la transpuesta de D (2, 4)
# Dimension de B (4, 5)
# Dimension de E (5, 4)
# La matriz resultante del producto de BC - 3D será 2 x 4
# La matriz resultante es :
#
# [[ 55255  19510  41550  57415]
#  [ 34707 -11032  -3318 -15261]]

# %%
# RESOLUCION 2. (e)
try:
    print("Dimension de B",B.shape)
    t_b = B.T
    print("Dimension de la transpuesta de B",t_b.shape)
    print("Dimension de D",D.shape)
    print("Dimension de E",E.shape)
    print("La matriz resultante del producto de BC - 3D será",E.shape[0],'x',D.shape[1])
    res2_e = t_b@D + E@D
    print("La matriz resultante es :",res2_e, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de B (4, 5)
# Dimension de la transpuesta de B (5, 4)
# Dimension de D (4, 2)
# Dimension de E (5, 4)
# La matriz resultante del producto de BC - 3D será 5 x 2
# La matriz resultante es :
#
# [[4070 2890]
#  [4065  351]
#  [5660 2340]
#  [ 945  227]
#  [1460 2820]]

# %%
# RESOLUCION 2. (f)
try:
    print("Dimension de B",B.shape)
    print("Dimension de A",A.shape)
    t_a = A.T
    print("Dimension de la transpuesta de A",t_a.shape)
    print("Dimension de D",D.shape)
    print("La matriz resultante del producto de BA^T será",B.shape[0],'x',t_a.shape[1])
    res2_f = B@t_a + D
    print("La matriz resultante es :",res2_f, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices permiten el producto pero no la suma.")
# Out:
# Dimension de B (4, 5)
# Dimension de A (4, 5)
# Dimension de la transpuesta de A (5, 4)
# Dimension de D (4, 2)
# La matriz resultante del producto de BA^T será 4 x 4
# Lo sentimos, las dimensiones de las matrices permiten el producto pero no la suma.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Hallar:
# ![image.png](attachment:image.png)

# %%
#CREAMOS LAS MATRICES QUE INDICA EL PROBLEMA
A = np.array([[3,0],
              [-1,2],
              [1,1]])
print()
print("La matriz A es: ",A,sep='\n\n')


B = np.array([[4,-1],
              [0,2]])
print()
print("La matriz B es: ",A,sep='\n\n')

C = np.array([[1,4,2],
              [3,1,5]])
print()
print("La matriz C es: ",C,sep='\n\n')

D = np.array([[1,5,2],
              [-1,0,1],
              [3,2,4]])
print()
print("La matriz D es: ",D,sep='\n\n')

E = np.array([[6,1,3],
              [-1,1,2],
              [4,1,3]])
print()
print("La matriz E es: ",E,sep='\n\n')
# Out:
# La matriz A es:
#
# [[ 3  0]
#  [-1  2]
#  [ 1  1]]
#
# La matriz B es:
#
# [[ 3  0]
#  [-1  2]
#  [ 1  1]]
#
# La matriz C es:
#
# [[1 4 2]
#  [3 1 5]]
#
# La matriz D es:
#
# [[ 1  5  2]
#  [-1  0  1]
#  [ 3  2  4]]
#
# La matriz E es:
#
# [[ 6  1  3]
#  [-1  1  2]
#  [ 4  1  3]]

# %%
#RESOLUCION 3. (a)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de E:",E.shape)
    print("La matriz resultante de la suma de D + E será:",D.shape[0],'x',D.shape[1])
    res3_a = D + E
    print("La matriz resultante es :",res3_a, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de D: (3, 3)
# Dimension de E: (3, 3)
# La matriz resultante de la suma de D + E será: 3 x 3
# La matriz resultante es :
#
# [[ 7  6  5]
#  [-2  1  3]
#  [ 7  3  7]]

# %%
#RESOLUCION 3. (b)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de E:",E.shape)
    print("La matriz resultante de la resta de D - E será:",D.shape[0],'x',D.shape[1])
    res3_b = D - E
    print("La matriz resultante es :",res3_b, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten la resta.")
# Out:
# Dimension de D: (3, 3)
# Dimension de E: (3, 3)
# La matriz resultante de la resta de D - E será: 3 x 3
# La matriz resultante es :
#
# [[-5  4 -1]
#  [ 0 -1 -1]
#  [-1  1  1]]

# %%
#RESOLUCION 3. (c)
try:
    print("Dimension de A:",A.shape)
    print("La matriz resultante de la suma de 5*A será:",A.shape[0],'x',A.shape[1])
    res3_c = 5*A
    print("La matriz resultante es :",res3_c, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de A: (3, 2)
# La matriz resultante de la suma de 5*A será: 3 x 2
# La matriz resultante es :
#
# [[15  0]
#  [-5 10]
#  [ 5  5]]

# %%
#RESOLUCION 3. (d)
try:
    print("Dimension de C:",C.shape)
    print("La matriz resultante de la suma de -7*C será:",C.shape[0],'x',C.shape[1])
    res3_d = -7*C
    print("La matriz resultante es :",res3_d, sep = '\n\n')
except ValueError:
    print("Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de C: (2, 3)
# La matriz resultante de la suma de -7*C será: 2 x 3
# La matriz resultante es :
#
# [[ -7 -28 -14]
#  [-21  -7 -35]]

# %%
#RESOLUCION 3. (e)
try:
    print("Dimension de B:",B.shape)
    print("Dimension de C:",C.shape)
    #print("La matriz resultante de la resta de 2B - C será:",C.shape[0],'x',C.shape[1])
    res3_e = 2*B-C
    print("La matriz resultante es :",res3_e, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la resta.")
# Out:
# Dimension de B: (2, 2)
# Dimension de C: (2, 3)
# Lo sentimos, las dimensiones de las matrices no permiten la resta.

# %%
#RESOLUCION 3. (f)
try:
    print("Dimension de E:",E.shape)
    print("Dimension de D:",D.shape)
    print("La matriz resultante de la resta de 4*E - 2*D será:",E.shape[0],'x',E.shape[1])
    res3_f = 4*E - 2*D
    print("La matriz resultante es :",res3_f, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la resta.")
# Out:
# Dimension de E: (3, 3)
# Dimension de D: (3, 3)
# La matriz resultante de la resta de 4*E - 2*D será: 3 x 3
# La matriz resultante es :
#
# [[22 -6  8]
#  [-2  4  6]
#  [10  0  4]]

# %%
#RESOLUCION 3. (g)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de E:",E.shape)
    print("La matriz resultante de la resta de -3(D+2E) será:",E.shape[0],'x',E.shape[1])
    res3_g = -3*(D+2*E)
    print("La matriz resultante es :",res3_g, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la resta.")
# Out:
# Dimension de D: (3, 3)
# Dimension de E: (3, 3)
# La matriz resultante de la resta de -3(D+2E) será: 3 x 3
# La matriz resultante es :
#
# [[-39 -21 -24]
#  [  9  -6 -15]
#  [-33 -12 -30]]

# %%
#RESOLUCION 3. (h)
res3_h = A - A
print("El resultado de A - A es:", res3_h, sep='\n\n')
# Out:
# El resultado de A - A es:
#
# [[0 0]
#  [0 0]
#  [0 0]]

# %%
#RESOLUCION 3. (i)
trace_D = np.trace(D)
print("La traza de la matriz D es: ")
print(trace_D)
# Out:
# La traza de la matriz D es:
# 5

# %%
#RESOLUCION 3. (j)
res_j = D - 3*E
trace_j = np.trace(res_j)
print("La traza de la matriz (D-3E) es: ")
print(trace_j)
# Out:
# La traza de la matriz (D-3E) es:
# -25

# %%
#RESOLUCION 3. (k)
prod_k = 7*B
trace_k = np.trace(prod_k)
ot_pr_k = 4*trace_k
print("La traza de la matriz 4*traza(7B) es: ")
print(ot_pr_k)
# Out:
# La traza de la matriz 4*traza(7B) es:
# 168

# %%
#RESOLUCION 3. (l)
print("La dimension de la matriz A es:", A.shape)
if  A.shape[0] != A.shape[1]:
    print("Lo sentimos, la traza de esta matriz no esta definida.")
else:
    res_l = np.trace(A)
    print(res_l)
# Out:
# La dimension de la matriz A es: (3, 2)
# Lo sentimos, la traza de esta matriz no esta definida.

# %% [markdown]
# #### Hallar:
# ![image.png](attachment:image.png)

# %%
#RESOLUCION 4. (a)
try:
    print("Dimension de A:",A.shape)
    print("Dimension de 2*A^t:",A.T.shape)
    print("Dimension de C:",C.shape)
    #print("La matriz resultante de la resta de 2A^t + C será:",C.shape[0],'x',C.shape[1])
    res4_a = 2*A.T+C
    print("La matriz resultante es :",res4_a, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de A: (3, 2)
# Dimension de 2*A^t: (2, 3)
# Dimension de C: (2, 3)
# La matriz resultante es :
#
# [[7 2 4]
#  [3 5 7]]

# %%
#RESOLUCION 4. (b)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de D^t:",D.T.shape)
    print("Dimension de E:",E.shape)
    print("Dimension de E^t:",E.T.shape)
    print("La matriz resultante de la resta de D^T - E^T será:",C.T.shape[0],'x',C.T.shape[1])
    res4_b = D.T - E.T
    print("La matriz resultante es :",res4_b, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de D: (3, 3)
# Dimension de D^t: (3, 3)
# Dimension de E: (3, 3)
# Dimension de E^t: (3, 3)
# La matriz resultante de la resta de D^T - E^T será: 3 x 2
# La matriz resultante es :
#
# [[-5  0 -1]
#  [ 4 -1  1]
#  [-1 -1  1]]

# %%
#RESOLUCION 4. (c)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de E:",C.shape)
    print("La matriz resultante de la resta de (D-E)^t será:",D.T.shape[0],'x',D.T.shape[1])
    res4_c = (D-E).T
    print("La matriz resultante es :",res4_c, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de D: (3, 3)
# Dimension de E: (2, 3)
# La matriz resultante de la resta de (D-E)^t será: 3 x 3
# La matriz resultante es :
#
# [[-5  0 -1]
#  [ 4 -1  1]
#  [-1 -1  1]]

# %%
#RESOLUCION 4. (d)
try:
    print("Dimension de B:",B.shape)
    print("Dimension de B^t:",B.T.shape)
    print("Dimension de C:",C.shape)
    print("Dimension de C^t:",C.T.shape)
    #print("La matriz resultante de la suma de B^T + 5*C^T será:",E.T.shape[0],'x',E.T.shape[1])
    res4_d = B.T + 5*C.T
    print("La matriz resultante es :",res4_d, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de B: (2, 2)
# Dimension de B^t: (2, 2)
# Dimension de C: (2, 3)
# Dimension de C^t: (3, 2)
# Lo sentimos, las dimensiones de las matrices no permiten la suma.

# %%
#RESOLUCION 4. (e)
try:
    print("Dimension de C:",C.shape)
    print("Dimension de C^t:",C.T.shape)
    print("Dimension de A:",A.shape)
    print("La matriz resultante de la resta de 1/2*C^T - 1/4A será:",A.shape[0],'x',A.shape[1])
    res4_e = (1/2)*C.T - (1/4)*A
    print("La matriz resultante es :",res4_e, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de C: (2, 3)
# Dimension de C^t: (3, 2)
# Dimension de A: (3, 2)
# La matriz resultante de la resta de 1/2*C^T - 1/4A será: 3 x 2
# La matriz resultante es :
#
# [[-0.25  1.5 ]
#  [ 2.25  0.  ]
#  [ 0.75  2.25]]

# %%
#RESOLUCION 4. (f)
try:
    print("Dimension de B:",B.shape)
    print("Dimension de B^t:",B.T.shape)
    print("La matriz resultante de la resta de B - B^T será:",B.shape[0],'x',B.shape[1])
    res4_f = B - B.T
    print("La matriz resultante es :",res4_f, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de B: (2, 2)
# Dimension de B^t: (2, 2)
# La matriz resultante de la resta de B - B^T será: 2 x 2
# La matriz resultante es :
#
# [[ 0 -1]
#  [ 1  0]]

# %%
#RESOLUCION 4. (g)
try:
    print("Dimension de E:",E.shape)
    print("Dimension de E^t:",E.T.shape)
    print("Dimension de D:",D.shape)
    print("Dimension de D^t:",D.T.shape)
    print("La matriz resultante de la resta de 2E^T - 3D^T será:",E.T.shape[0],'x',E.T.shape[1])
    res4_g = 2*E.T - 3*D.T 
    print("La matriz resultante es :",res4_g, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de E: (3, 3)
# Dimension de E^t: (3, 3)
# Dimension de D: (3, 3)
# Dimension de D^t: (3, 3)
# La matriz resultante de la resta de 2E^T - 3D^T será: 3 x 3
# La matriz resultante es :
#
# [[  9   1  -1]
#  [-13   2  -4]
#  [  0   1  -6]]

# %%
#RESOLUCION 4. (h)
try:
    print("Dimension de E:",E.shape)
    print("Dimension de E^t:",E.T.shape)
    print("Dimension de D:",D.shape)
    print("Dimension de D^t:",D.T.shape)
    print("La matriz resultante de la resta de (2E^T - 3D^T)^T será:",E.shape[0],'x',E.shape[1])
    res4_h = (2*E.T - 3*D.T).T 
    print("La matriz resultante es :",res4_h, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de E: (3, 3)
# Dimension de E^t: (3, 3)
# Dimension de D: (3, 3)
# Dimension de D^t: (3, 3)
# La matriz resultante de la resta de (2E^T - 3D^T)^T será: 3 x 3
# La matriz resultante es :
#
# [[  9 -13   0]
#  [  1   2   1]
#  [ -1  -4  -6]]

# %%
#RESOLUCION 4. (i)
try:
    print("Dimension de C:",C.shape)
    print("Dimension de D:",D.shape)
    print("Dimension de E:",E.shape)
    print("La matriz resultante de la resta de (CD)E será:",C.shape[0],'x',E.shape[1])
    res4_i = np.dot(C,D).dot(E)
    print("La matriz resultante es :",res4_i, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de C: (2, 3)
# Dimension de D: (3, 3)
# Dimension de E: (3, 3)
# La matriz resultante de la resta de (CD)E será: 2 x 3
# La matriz resultante es :
#
# [[ 65  26  69]
#  [185  69 182]]

# %%
#RESOLUCION 4. (j)
try:
    print("Dimension de C:",C.shape)
    print("Dimension de B:",B.shape)
    print("Dimension de A:",A.shape)
    #print("La matriz resultante de la resta de C(BA) será:",C.shape[0],'x',A.shape[1])
    print()
    res4_j = C @ (B@A)
    print("La matriz resultante es :",res4_j, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de C: (2, 3)
# Dimension de B: (2, 2)
# Dimension de A: (3, 2)
#
# Lo sentimos, las dimensiones de las matrices no permiten el producto.

# %%
#RESOLUCION 4. (k)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de E:",E.shape)
    print("Dimension de E^T:",E.T.shape)
    #print("La matriz resultante de la resta de C(BA) será:",C.shape[0],'x',A.shape[1])
    print()
    res4_k = np.trace(np.dot(D,E.T))
    print("La matriz resultante es :",res4_k, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de D: (3, 3)
# Dimension de E: (3, 3)
# Dimension de E^T: (3, 3)
#
# La matriz resultante es :
#
# 46

# %%
#RESOLUCION 4. (l)
try:
    print("Dimension de B:",B.shape)
    print("Dimension de C:",C.shape)
    #print("La matriz resultante de la resta de C(BA) será:",C.shape[0],'x',A.shape[1])
    print()
    res4_l = np.dot(B,C)
    if res4_l.shape[0] != res4_l.shape[1]:
        print("Lo sentimos, la traza no está definida porque el producto no es una matriz cuadrada.")
    else:
        res_tr = np.trace(res4_l)
        print("La matriz resultante es :",res_tr, sep = '\n\n')
    
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten hallar la traza.")
# Out:
# Dimension de B: (2, 2)
# Dimension de C: (2, 3)
#
# Lo sentimos, la traza no está definida porque el producto no es una matriz cuadrada.

# %% [markdown]
# #### Hallar:
# ![image.png](attachment:image.png)

# %%
#RESOLUCION 5. (a)
try:
    print("Dimension de A:",A.shape)
    print("Dimension de B:",B.shape)
    print("La matriz resultante de la resta de AB será:",A.shape[0],'x',B.shape[1])
    res5_a = A@B 
    print("La matriz resultante es :",res5_a, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten la suma.")
# Out:
# Dimension de A: (3, 2)
# Dimension de B: (2, 2)
# La matriz resultante de la resta de AB será: 3 x 2
# La matriz resultante es :
#
# [[12 -3]
#  [-4  5]
#  [ 4  1]]

# %%
#RESOLUCION 5. (b)
try:
    print("Dimension de B:",B.shape)
    print("Dimension de A:",A.shape)
    #print("La matriz resultante de la resta de AB será:",A.shape[0],'x',B.shape[1])
    res5_b = B@A 
    print("La matriz resultante es :",res5_b, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de B: (2, 2)
# Dimension de A: (3, 2)
# Lo sentimos, las dimensiones de las matrices no permiten el producto.

# %%
#RESOLUCION 5. (c)
try:
    print("Dimension de E:",E.shape)
    print("Dimension de D:",D.shape)
    print("La matriz resultante del producto (3E)D de AB será:",E.shape[0],'x',D.shape[1])
    res5_c = (3*E)@D 
    print("La matriz resultante es :",res5_c, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de E: (3, 3)
# Dimension de D: (3, 3)
# La matriz resultante del producto (3E)D de AB será: 3 x 3
# La matriz resultante es :
#
# [[ 42 108  75]
#  [ 12  -3  21]
#  [ 36  78  63]]

# %%
#RESOLUCION 5. (d)
try:
    print("Dimension de A:",A.shape)
    print("Dimension de B:",B.shape)
    print("Dimension de C:",C.shape)
    print("La matriz resultante del producto (AB)C será:",A.shape[0],'x',C.shape[1])
    res5_d = (A@B)@C
    print("La matriz resultante es :",res5_d, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de A: (3, 2)
# Dimension de B: (2, 2)
# Dimension de C: (2, 3)
# La matriz resultante del producto (AB)C será: 3 x 3
# La matriz resultante es :
#
# [[  3  45   9]
#  [ 11 -11  17]
#  [  7  17  13]]

# %%
#RESOLUCION 5. (e)
try:
    print("Dimension de A:",A.shape)
    print("Dimension de B:",B.shape)
    print("Dimension de C:",C.shape)
    print("La matriz resultante del producto A(BC) será:",A.shape[0],'x',C.shape[1])
    res5_e = A@(B@C)
    print("La matriz resultante es :",res5_e, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de A: (3, 2)
# Dimension de B: (2, 2)
# Dimension de C: (2, 3)
# La matriz resultante del producto A(BC) será: 3 x 3
# La matriz resultante es :
#
# [[  3  45   9]
#  [ 11 -11  17]
#  [  7  17  13]]

# %%
#RESOLUCION 5. (f)
try:
    print("Dimension de C:",C.shape)
    print("Dimension de C.T:",C.T.shape)
    print("La matriz resultante del producto CC^T será:",C.shape[0],'x',C.shape[0])
    res5_f = C@C.T
    print("La matriz resultante es :",res5_f, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de C: (2, 3)
# Dimension de C.T: (3, 2)
# La matriz resultante del producto CC^T será: 2 x 2
# La matriz resultante es :
#
# [[21 17]
#  [17 35]]

# %%
#RESOLUCION 5. (g)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de A:",A.shape)
    print("La matriz resultante del producto (DA).T será:",A.shape[1],'x',D.shape[0])
    prod5 = np.dot(D,A)
    res5_g = prod5.T
    print("La matriz resultante es :",res5_g, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de D: (3, 3)
# Dimension de A: (3, 2)
# La matriz resultante del producto (DA).T será: 2 x 3
# La matriz resultante es :
#
# [[ 0 -2 11]
#  [12  1  8]]

# %%
#RESOLUCION 5. (h)
try:
    print("Dimension de C:",C.shape)
    print("Dimension de C.T:",C.T.shape)
    print("Dimension de B:",B.shape)
    print("Dimension de A:",A.shape)
    print("Dimension de A.T:",A.T.shape)
    print("La matriz resultante del producto (C^TB)A^T será:",A.shape[0],'x',A.shape[0])
    res5_h = np.dot(C.T,B).dot(A.T)
    print("La matriz resultante es :",res5_h, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de C: (2, 3)
# Dimension de C.T: (3, 2)
# Dimension de B: (2, 2)
# Dimension de A: (3, 2)
# Dimension de A.T: (2, 3)
# La matriz resultante del producto (C^TB)A^T será: 3 x 3
# La matriz resultante es :
#
# [[ 12   6   9]
#  [ 48 -20  14]
#  [ 24   8  16]]

# %%
#RESOLUCION 5. (i)
try:
    print("Dimension de D:",D.shape)
    print("Dimension de D.T:",D.T.shape)
    #print("La matriz resultante del producto tr(DD.T) será:",A.shape[0],'x',A.shape[0])
    res5_i = np.trace(np.dot(D,D.T))
    print("La traza resultante es :",res5_i, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de D: (3, 3)
# Dimension de D.T: (3, 3)
# La traza resultante es :
#
# 61

# %%
#RESOLUCION 5. (j)
try:
    print("Dimension de E:",E.shape)
    print("Dimension de E.T:",E.T.shape)
    print("Dimension de D:",D.shape)
    #print("La matriz resultante del producto tr(DD.T) será:",A.shape[0],'x',A.shape[0])
    res5_j = np.trace(4*E.T - D)
    print("La traza resultante es :",res5_j, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de E: (3, 3)
# Dimension de E.T: (3, 3)
# Dimension de D: (3, 3)
# La traza resultante es :
#
# 35

# %%
#RESOLUCION 5. (k)
try:
    print("Dimension de C:",C.shape)
    print("Dimension de C.T:",C.T.shape)
    print("Dimension de A:",A.shape)
    print("Dimension de A.T:",A.T.shape)
    print("Dimension de E:",E.shape)
    print("Dimension de E.T:",E.T.shape)
    #print("La matriz resultante del producto tr(DD.T) será:",A.shape[0],'x',A.shape[0])
    res5_k = np.trace(C.T@A.T + 2*E.T)
    print("La traza resultante es :",res5_k, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de C: (2, 3)
# Dimension de C.T: (3, 2)
# Dimension de A: (3, 2)
# Dimension de A.T: (2, 3)
# Dimension de E: (3, 3)
# Dimension de E.T: (3, 3)
# La traza resultante es :
#
# 28

# %%
#RESOLUCION 5. (l)
try:
    print("Dimension de E:",E.shape)
    print("Dimension de C:",C.shape)
    print("Dimension de C.T:",C.T.shape)
    print("Dimension de A:",A.shape)
    #print("La matriz resultante del producto tr(DD.T) será:",A.shape[0],'x',A.shape[0])
    res5_l = np.trace((E@C.T).T@A)
    print("La traza resultante es :",res5_l, sep = '\n\n')
except ValueError:
    print(f"Lo sentimos, las dimensiones de las matrices no permiten el producto.")
# Out:
# Dimension de E: (3, 3)
# Dimension de C: (2, 3)
# Dimension de C.T: (3, 2)
# Dimension de A: (3, 2)
# La traza resultante es :
#
# 99

# %% [markdown]
# #### Hallar:
# ![image.png](attachment:image.png)
